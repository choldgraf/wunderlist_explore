# %%
import pandas as pd
import json
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_file = '../data/wunderlist-2015048-14-43-11.json'

# %%
with open(data_file, 'r') as f:
    data = json.load(f)

# %% [markdown]
# ### Munging

# %%
task_data = data['data']['tasks']
task_data = pd.DataFrame(task_data)

# %%
list_data = data['data']['lists']
list_data = pd.DataFrame(list_data)

# %%
task_data['creation_week'] = task_data['created_at'].apply(lambda a: pd.to_datetime(a).week)
task_data['creation_year'] = task_data['created_at'].apply(lambda a: pd.to_datetime(a).year)

# %%
# Renaming columns
rename_cols = {lid: list_data[(list_data['id'] == lid).values]['title'].values[0]
                               for lid in task_data_time.columns}

# %%
task_data_time = task_data.groupby(('creation_week', 'creation_year', 'list_id')).count()['created_at'].unstack('list_id')
task_data_time = task_data_time.reorder_levels(('creation_year', 'creation_week')).sort_index()
task_data_time = task_data_time.rename(columns=rename_cols)

# %% [markdown]
# ### Plotting

# %%
ax = task_data_time.plot(figsize=(15, 5))
ax.set_title('Weekly to-do items per project')
